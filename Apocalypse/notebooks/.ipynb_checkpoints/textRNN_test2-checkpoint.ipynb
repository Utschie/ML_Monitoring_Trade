# %%
#本程序是用来测试textRNN_half在平衡数据集里性能的程序
#原程序在非平衡数据集中训练测试的结果是52%左右
#现在测试一下在平衡数据集中的表现，如果好，则说明这样的数据预处理思路有效
import os
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
import sys
import pandas as pd
import numpy as np
import csv
import random
import re
from sklearn.decomposition import TruncatedSVD
from torch.nn.utils.rnn import pad_sequence#用来填充序列
import time
from prefetch_generator import BackgroundGenerator
from torch.utils.tensorboard import SummaryWriter
from pywick.optimizers.nadam import Nadam#使用pywick包里的nadam优化器
from torch.optim import lr_scheduler
with open('/home/jsy/data/cidlist_complete.csv') as f:
    reader = csv.reader(f)
    cidlist = [row[1] for row in reader]#得到cid对应表
cidlist = list(map(float,cidlist))#把各个元素字符串类型转成浮点数类型
class DataLoaderX(DataLoader):
    def __iter__(self):
        return BackgroundGenerator(super().__iter__())
class BisaiDataset(Dataset):#数据预处理器
    def __init__(self,filepath):#filepath是个列表
        with open(filepath,'r') as f:#读取filepath文件并做成filelist列表
            self.filelist = []
            for line in f:
                self.filelist.append(line.strip('\n'))
        self.lablelist = pd.read_csv('/home/jsy/data/lablelist.csv',index_col = 0)#比赛id及其对应赛果的列表
        self.lables = {'win':0,'draw':1,'lose':2}#分类问题要从0开始编号,而且要对应好了表中的顺序编，
    
    def __getitem__(self, index):
        #todo
        # 1. Read one data from file (e.g. using numpy.fromfile, PIL.Image.open).
        #这里需要注意的是，第一步：read one data，是一个dat
        data_path = self.filelist[index]
        bisai_id = int(re.findall(r'/(\d*?).csv',data_path)[0])
        # 2. Preprocess the data (e.g. torchvision.Transform).
        data = self.csv2frame(data_path)
        # 3. Return a data pair (e.g. image and label).
        lable = self.lablelist.loc[bisai_id].result
        lable = self.lables[lable]
        return data,lable      
       
    def __len__(self):
        # You should change 0 to the total size of your dataset.
        return len(self.filelist)

    def csv2frame(self,filepath):#给出单场比赛的csv文件路径，并转化成帧列表和对应变帧时间列表，以及比赛结果
        data = pd.read_csv(filepath)#读取文件
        data = data.drop(columns=['league','zhudui','kedui','companyname'])#去除非数字的列
        frametimelist=data.frametime.value_counts().sort_index(ascending=False).index#将frametime的值读取成列表
        framelist =list()#framelist为一个空列表,长度与frametimelist相同,一定要规定好具体形状和float类型，否则dataloader无法读取
        '''
        此处两个循环算法太慢，用pandas更慢，完全抛弃pandas后，数据处理速度从109秒降到了10秒，降到10秒后cpu利用率20%，再往上提也提不上去了，可能需要C++或C来写了
        '''
        new_data = np.array(data)
        lables = new_data[:,0]
        if len(frametimelist)>250:
            frametimelist = [frametimelist[0]]+random.sample(list(frametimelist)[1:-1],248)+[frametimelist[-1]]#如果长度大于500,保留头尾，并在中间随机抽取498个，共计500个
            frametimelist.sort(reverse=True)#并降序排列
        for i in frametimelist:
            state = new_data[lables==i]#从第一次变盘开始得到当次转移
            #state = np.array(state)#不必转成numpy多维数组，因为已经是了
            state = np.delete(state,(0,1), axis=-1)#去掉frametime和cid
            #在填充成矩阵之前需要知道所有数据中到底有多少个cid
            framelist.append(state)
        frametimelist = np.array(frametimelist)
        vectensor = self.mrx2vec(framelist)
        len_frame = vectensor.shape[0]
        if len_frame<250:
            vectensor = np.concatenate((np.zeros((250-len_frame,10),dtype=np.float64),vectensor),axis=0)#如果不足500，则在前面用0填充
        vectensor = torch.from_numpy(vectensor)
        return vectensor#传出一个帧列表,也可以把frametimelist一并传出来，此处暂不考虑位置参数的问题
    
    def tsvd(self,frame):
        tsvd = TruncatedSVD(1)
        if frame.shape[0] != 1:
            newframe = tsvd.fit_transform(np.transpose(frame))#降维成（1,10）的矩阵
        else:
            return frame.reshape((10,1))#第一行需要reshape一下
        return newframe
    
    def mrx2vec(self,flist):#把截断奇异值的方法把矩阵变成向量(matrix2vec/img2vec)，传入：len(frametimelist)*(306*10),传出：len(frametimelist)*10
        vectensor = np.array(list(map(self.tsvd,flist))).squeeze(2)
        #veclist = veclist.transpose()
        #vectensor = torch.from_numpy(veclist)#转成张量
        return vectensor#传出一个形状为(1,序列长度,10)的张量，因为后面传入模型之前，还需要做一下pad_sequence(0维是batch_size维)

 


class Lstm(nn.Module):#在模型建立之处就把它默认初始化
    def __init__(self):
        super().__init__()
        self.encoder = nn.LSTM(input_size=10, 
                                hidden_size=250,#选择对帧进行保留首尾的均匀截断采样
                                num_layers=1,#暂时就只有一层
                                bidirectional=True)
        nn.init.orthogonal_(self.encoder.weight_ih_l0)
        nn.init.orthogonal_(self.encoder.weight_hh_l0)
        nn.init.constant_(self.encoder.bias_ih_l0,0.0)
        nn.init.constant_(self.encoder.bias_hh_l0,0.0)
        self.decoder = nn.Sequential(
            nn.Linear(1000, 250),#把LSTM的输出
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(250, 3)
        )
        nn.init.normal_(self.decoder[0].weight,mean=0.0)
        nn.init.constant_(self.decoder[0].bias, 0.0)
        nn.init.normal_(self.decoder[3].weight,mean=0.0)
        nn.init.constant_(self.decoder[3].bias, 0.0)

    def forward(self,inputs):
        output, _= self.encoder(inputs.permute(1,0,2))#inputs需要转置一下再输入lstm层，因为pytorch要求第0维为长度，第二维才是batch_size
        encoding = torch.cat((output[0], output[-1]), -1)#双向的lstm，就把两个都放进去
        return self.decoder(encoding)#把最后一个时间步的输出输入MLP


def get_parameter_number(model):#参数统计
    total_num = sum(p.numel() for p in model.parameters())
    trainable_num = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return {'Total': total_num, 'Trainable': trainable_num}



if __name__ == "__main__":
    checkpoint_path = '/home/jsy/log/checkpoints/checkpoint.pth'#ckpoint文件夹需要提前建立
    test_path1 = '/home/jsy/balanced_train_path.txt'
    test_path2 = '/home/jsy/balanced_test_path.txt'
    test_set1 = BisaiDataset(test_path1)#验证集
    test_set2 = BisaiDataset(test_path2)
    print('数据集读取完成')
    test_loader1 = DataLoaderX(test_set1, 64 ,shuffle=True,num_workers=4,pin_memory=True)#num_workers>0情况下无法在交互模式下运行
    test_loader2 = DataLoaderX(test_set2, 64, shuffle=True,num_workers=4,pin_memory=True)#验证dataloader
    print('dataloader准备完成')
    net = Lstm().double().cuda()#双精度
    print('网络构建完成')
    stat1 = get_parameter_number(net)
    print(str(stat1))
    if os.path.exists(checkpoint_path):
        checkpoint = torch.load(checkpoint_path)
        net.load_state_dict(checkpoint['model_state_dict'])
    loss = nn.CrossEntropyLoss()
    print('开始验证......')
    net.eval()
    torch.cuda.empty_cache()#释放一下显存
    with torch.no_grad():#这样在验证时显存才不会爆
        test_output = torch.zeros((1,3))
        test_y = torch.zeros((1)).long()#得是long类型
        test_counter = 0
        #先测试test_loader1
        start = time.time()
        for x,y in iter(test_loader1):
            x = x.double().cuda()
            output = net(x).cpu()#把输出转到内存
            test_output = torch.cat((test_output,output),0)#把这一个batch的输出连起来
            test_y = torch.cat((test_y,y),0)#把这一个batch的lable连起来
            #torch.cuda.empty_cache()
            test_counter+=1
            print('test_set1已完成'+str(test_counter)+'个batch')
        #验证输出和验证lable的第一个元素都是0，鉴于到时候占比很小就不删除了
        print('计算结果......')
        l_test = loss(test_output,test_y)#用整个验证集的输出和lable算一个总平均loss(nn.CrossEntropyLoss默认就是求平均值)
        prediction = torch.argmax(test_output, 1)#找出每场比赛预测输出的最大值的坐标
        correct = (prediction == test_y).sum().float()#找出预测正确的总个数
        accuracy1 = correct/len(test_y)#计算Top-1正确率,总共就三分类，就不看top-2的了
        end = time.time()
        print('test_set1测试完成,用时'+str(end-start)+'秒,准确率为'+str(accuracy1))
        #再测试test_loader2
        test_output = torch.zeros((1,3))
        test_y = torch.zeros((1)).long()#得是long类型
        test_counter = 0
        start = time.time()
        for x,y in iter(test_loader2):
            x = x.double().cuda()
            output = net(x).cpu()#把输出转到内存
            test_output = torch.cat((test_output,output),0)#把这一个batch的输出连起来
            test_y = torch.cat((test_y,y),0)#把这一个batch的lable连起来
            #torch.cuda.empty_cache()
            test_counter+=1
            print('test_set2已完成'+str(test_counter)+'个batch')
        #验证输出和验证lable的第一个元素都是0，鉴于到时候占比很小就不删除了
        print('计算结果......')
        l_test = loss(test_output,test_y)#用整个验证集的输出和lable算一个总平均loss(nn.CrossEntropyLoss默认就是求平均值)
        prediction = torch.argmax(test_output, 1)#找出每场比赛预测输出的最大值的坐标
        correct = (prediction == test_y).sum().float()#找出预测正确的总个数
        accuracy2 = correct/len(test_y)#计算Top-1正确率,总共就三分类，就不看top-2的了
        end = time.time()
        print('test_set2测试完成,用时'+str(end-start)+'秒,准确率为'+str(accuracy2))
    print('test_set1的Top-1精确度为'+str(accuracy1))
    print('test_set2的Top-1精确度为'+str(accuracy2))
# Out:
# 数据集读取完成
# dataloader准备完成
# 网络构建完成
# {'Total': 775003, 'Trainable': 775003}
# 开始验证......
# test_set1已完成1个batch
# test_set1已完成2个batch
# test_set1已完成3个batch
# test_set1已完成4个batch
# test_set1已完成5个batch
# test_set1已完成6个batch
# test_set1已完成7个batch
# test_set1已完成8个batch
# test_set1已完成9个batch
# test_set1已完成10个batch
# test_set1已完成11个batch
# test_set1已完成12个batch
# test_set1已完成13个batch
# test_set1已完成14个batch
# test_set1已完成15个batch
# test_set1已完成16个batch
# test_set1已完成17个batch
# test_set1已完成18个batch
# test_set1已完成19个batch
# test_set1已完成20个batch
# test_set1已完成21个batch
# test_set1已完成22个batch
# test_set1已完成23个batch
# test_set1已完成24个batch
# test_set1已完成25个batch
# test_set1已完成26个batch
# test_set1已完成27个batch
# test_set1已完成28个batch
# test_set1已完成29个batch
# test_set1已完成30个batch
# test_set1已完成31个batch
# test_set1已完成32个batch
# test_set1已完成33个batch
# test_set1已完成34个batch
# test_set1已完成35个batch
# test_set1已完成36个batch
# test_set1已完成37个batch
# test_set1已完成38个batch
# test_set1已完成39个batch
# test_set1已完成40个batch
# test_set1已完成41个batch
# test_set1已完成42个batch
# test_set1已完成43个batch
# test_set1已完成44个batch
# test_set1已完成45个batch
# test_set1已完成46个batch
# test_set1已完成47个batch
# test_set1已完成48个batch
# test_set1已完成49个batch
# test_set1已完成50个batch
# test_set1已完成51个batch
# test_set1已完成52个batch
# test_set1已完成53个batch
# test_set1已完成54个batch
# test_set1已完成55个batch
# test_set1已完成56个batch
# test_set1已完成57个batch
# test_set1已完成58个batch
# test_set1已完成59个batch
# test_set1已完成60个batch
# test_set1已完成61个batch
# test_set1已完成62个batch
# test_set1已完成63个batch
# test_set1已完成64个batch
# test_set1已完成65个batch
# test_set1已完成66个batch
# test_set1已完成67个batch
# test_set1已完成68个batch
# test_set1已完成69个batch
# test_set1已完成70个batch
# test_set1已完成71个batch
# test_set1已完成72个batch
# test_set1已完成73个batch
# test_set1已完成74个batch
# test_set1已完成75个batch
# test_set1已完成76个batch
# test_set1已完成77个batch
# test_set1已完成78个batch
# test_set1已完成79个batch
# test_set1已完成80个batch
# test_set1已完成81个batch
# test_set1已完成82个batch
# test_set1已完成83个batch
# test_set1已完成84个batch
# test_set1已完成85个batch
# test_set1已完成86个batch
# test_set1已完成87个batch
# test_set1已完成88个batch
# test_set1已完成89个batch
# test_set1已完成90个batch
# test_set1已完成91个batch
# test_set1已完成92个batch
# test_set1已完成93个batch
# test_set1已完成94个batch
# test_set1已完成95个batch
# test_set1已完成96个batch
# test_set1已完成97个batch
# test_set1已完成98个batch
# test_set1已完成99个batch
# test_set1已完成100个batch
# test_set1已完成101个batch
# test_set1已完成102个batch
# test_set1已完成103个batch
# test_set1已完成104个batch
# test_set1已完成105个batch
# test_set1已完成106个batch
# test_set1已完成107个batch
# test_set1已完成108个batch
# test_set1已完成109个batch
# test_set1已完成110个batch
# test_set1已完成111个batch
# test_set1已完成112个batch
# test_set1已完成113个batch
# test_set1已完成114个batch
# test_set1已完成115个batch
# test_set1已完成116个batch
# test_set1已完成117个batch
# test_set1已完成118个batch
# test_set1已完成119个batch
# test_set1已完成120个batch
# test_set1已完成121个batch
# test_set1已完成122个batch
# test_set1已完成123个batch
# test_set1已完成124个batch
# test_set1已完成125个batch
# test_set1已完成126个batch
# test_set1已完成127个batch
# test_set1已完成128个batch
# test_set1已完成129个batch
# test_set1已完成130个batch
# test_set1已完成131个batch
# test_set1已完成132个batch
# test_set1已完成133个batch
# test_set1已完成134个batch
# test_set1已完成135个batch
# test_set1已完成136个batch
# test_set1已完成137个batch
# test_set1已完成138个batch
# test_set1已完成139个batch
# test_set1已完成140个batch
# test_set1已完成141个batch
# test_set1已完成142个batch
# test_set1已完成143个batch
# test_set1已完成144个batch
# test_set1已完成145个batch
# test_set1已完成146个batch
# test_set1已完成147个batch
# test_set1已完成148个batch
# test_set1已完成149个batch
# test_set1已完成150个batch
# test_set1已完成151个batch
# test_set1已完成152个batch
# test_set1已完成153个batch
# test_set1已完成154个batch
# test_set1已完成155个batch
# test_set1已完成156个batch
# test_set1已完成157个batch
# test_set1已完成158个batch
# test_set1已完成159个batch
# test_set1已完成160个batch
# test_set1已完成161个batch
# test_set1已完成162个batch
# test_set1已完成163个batch
# test_set1已完成164个batch
# test_set1已完成165个batch
# test_set1已完成166个batch
# test_set1已完成167个batch
# test_set1已完成168个batch
# test_set1已完成169个batch
# test_set1已完成170个batch
# test_set1已完成171个batch
# test_set1已完成172个batch
# test_set1已完成173个batch
# test_set1已完成174个batch
# test_set1已完成175个batch
# test_set1已完成176个batch
# test_set1已完成177个batch
# test_set1已完成178个batch
# test_set1已完成179个batch
# test_set1已完成180个batch
# test_set1已完成181个batch
# test_set1已完成182个batch
# test_set1已完成183个batch
# test_set1已完成184个batch
# test_set1已完成185个batch
# test_set1已完成186个batch
# test_set1已完成187个batch
# test_set1已完成188个batch
# test_set1已完成189个batch
# test_set1已完成190个batch
# test_set1已完成191个batch
# test_set1已完成192个batch
# test_set1已完成193个batch
# test_set1已完成194个batch
# test_set1已完成195个batch
# test_set1已完成196个batch
# test_set1已完成197个batch
# test_set1已完成198个batch
# test_set1已完成199个batch
# test_set1已完成200个batch
# test_set1已完成201个batch
# test_set1已完成202个batch
# test_set1已完成203个batch
# test_set1已完成204个batch
# test_set1已完成205个batch
# test_set1已完成206个batch
# test_set1已完成207个batch
# test_set1已完成208个batch
# test_set1已完成209个batch
# test_set1已完成210个batch
# test_set1已完成211个batch
# test_set1已完成212个batch
# test_set1已完成213个batch
# test_set1已完成214个batch
# test_set1已完成215个batch
# test_set1已完成216个batch
# test_set1已完成217个batch
# test_set1已完成218个batch
# test_set1已完成219个batch
# test_set1已完成220个batch
# test_set1已完成221个batch
# test_set1已完成222个batch
# test_set1已完成223个batch
# test_set1已完成224个batch
# test_set1已完成225个batch
# test_set1已完成226个batch
# test_set1已完成227个batch
# test_set1已完成228个batch
# test_set1已完成229个batch
# test_set1已完成230个batch
# test_set1已完成231个batch
# test_set1已完成232个batch
# test_set1已完成233个batch
# test_set1已完成234个batch
# test_set1已完成235个batch
# test_set1已完成236个batch
# test_set1已完成237个batch
# test_set1已完成238个batch
# test_set1已完成239个batch
# test_set1已完成240个batch
# test_set1已完成241个batch
# test_set1已完成242个batch
# test_set1已完成243个batch
# test_set1已完成244个batch
# test_set1已完成245个batch
# test_set1已完成246个batch
# test_set1已完成247个batch
# test_set1已完成248个batch
# test_set1已完成249个batch
# test_set1已完成250个batch
# test_set1已完成251个batch
# test_set1已完成252个batch
# test_set1已完成253个batch
# test_set1已完成254个batch
# test_set1已完成255个batch
# test_set1已完成256个batch
# test_set1已完成257个batch
# test_set1已完成258个batch
# test_set1已完成259个batch
# test_set1已完成260个batch
# test_set1已完成261个batch
# test_set1已完成262个batch
# test_set1已完成263个batch
# test_set1已完成264个batch
# test_set1已完成265个batch
# test_set1已完成266个batch
# test_set1已完成267个batch
# test_set1已完成268个batch
# test_set1已完成269个batch
# test_set1已完成270个batch
# test_set1已完成271个batch
# test_set1已完成272个batch
# test_set1已完成273个batch
# test_set1已完成274个batch
# test_set1已完成275个batch
# test_set1已完成276个batch
# test_set1已完成277个batch
# test_set1已完成278个batch
# test_set1已完成279个batch
# test_set1已完成280个batch
# test_set1已完成281个batch
# test_set1已完成282个batch
# test_set1已完成283个batch
# test_set1已完成284个batch
# test_set1已完成285个batch
# test_set1已完成286个batch
# test_set1已完成287个batch
# test_set1已完成288个batch
# test_set1已完成289个batch
# test_set1已完成290个batch
# test_set1已完成291个batch
# test_set1已完成292个batch
# test_set1已完成293个batch
# test_set1已完成294个batch
# test_set1已完成295个batch
# test_set1已完成296个batch
# test_set1已完成297个batch
# test_set1已完成298个batch
# test_set1已完成299个batch
# test_set1已完成300个batch
# test_set1已完成301个batch
# test_set1已完成302个batch
# test_set1已完成303个batch
# test_set1已完成304个batch
# test_set1已完成305个batch
# test_set1已完成306个batch
# test_set1已完成307个batch
# test_set1已完成308个batch
# test_set1已完成309个batch
# test_set1已完成310个batch
# test_set1已完成311个batch
# test_set1已完成312个batch
# test_set1已完成313个batch
# test_set1已完成314个batch
# test_set1已完成315个batch
# test_set1已完成316个batch
# test_set1已完成317个batch
# test_set1已完成318个batch
# test_set1已完成319个batch
# test_set1已完成320个batch
# test_set1已完成321个batch
# test_set1已完成322个batch
# test_set1已完成323个batch
# test_set1已完成324个batch
# test_set1已完成325个batch
# test_set1已完成326个batch
# test_set1已完成327个batch
# test_set1已完成328个batch
# test_set1已完成329个batch
# test_set1已完成330个batch
# test_set1已完成331个batch
# test_set1已完成332个batch
# test_set1已完成333个batch
# test_set1已完成334个batch
# test_set1已完成335个batch
# test_set1已完成336个batch
# test_set1已完成337个batch
# test_set1已完成338个batch
# test_set1已完成339个batch
# test_set1已完成340个batch
# test_set1已完成341个batch
# test_set1已完成342个batch
# test_set1已完成343个batch
# test_set1已完成344个batch
# test_set1已完成345个batch
# test_set1已完成346个batch
# test_set1已完成347个batch
# test_set1已完成348个batch
# test_set1已完成349个batch
# test_set1已完成350个batch
# test_set1已完成351个batch
# test_set1已完成352个batch
# test_set1已完成353个batch
# test_set1已完成354个batch
# test_set1已完成355个batch
# test_set1已完成356个batch
# test_set1已完成357个batch
# test_set1已完成358个batch
# test_set1已完成359个batch
# test_set1已完成360个batch
# test_set1已完成361个batch
# test_set1已完成362个batch
# test_set1已完成363个batch
# test_set1已完成364个batch
# test_set1已完成365个batch
# test_set1已完成366个batch
# test_set1已完成367个batch
# test_set1已完成368个batch
# test_set1已完成369个batch
# test_set1已完成370个batch
# test_set1已完成371个batch
# test_set1已完成372个batch
# test_set1已完成373个batch
# test_set1已完成374个batch
# test_set1已完成375个batch
# test_set1已完成376个batch
# test_set1已完成377个batch
# test_set1已完成378个batch
# test_set1已完成379个batch
# test_set1已完成380个batch
# test_set1已完成381个batch
# test_set1已完成382个batch
# test_set1已完成383个batch
# test_set1已完成384个batch
# test_set1已完成385个batch
# test_set1已完成386个batch
# test_set1已完成387个batch
# test_set1已完成388个batch
# test_set1已完成389个batch
# test_set1已完成390个batch
# test_set1已完成391个batch
# test_set1已完成392个batch
# test_set1已完成393个batch
# test_set1已完成394个batch
# test_set1已完成395个batch
# test_set1已完成396个batch
# test_set1已完成397个batch
# test_set1已完成398个batch
# test_set1已完成399个batch
# test_set1已完成400个batch
# test_set1已完成401个batch
# test_set1已完成402个batch
# test_set1已完成403个batch
# test_set1已完成404个batch
# test_set1已完成405个batch
# test_set1已完成406个batch
# test_set1已完成407个batch
# test_set1已完成408个batch
# test_set1已完成409个batch
# test_set1已完成410个batch
# test_set1已完成411个batch
# test_set1已完成412个batch
# test_set1已完成413个batch
# test_set1已完成414个batch
# test_set1已完成415个batch
# test_set1已完成416个batch
# test_set1已完成417个batch
# test_set1已完成418个batch
# test_set1已完成419个batch
# test_set1已完成420个batch
# test_set1已完成421个batch
# test_set1已完成422个batch
# test_set1已完成423个batch
# test_set1已完成424个batch
# test_set1已完成425个batch
# test_set1已完成426个batch
# test_set1已完成427个batch
# test_set1已完成428个batch
# test_set1已完成429个batch
# test_set1已完成430个batch
# test_set1已完成431个batch
# test_set1已完成432个batch
# test_set1已完成433个batch
# test_set1已完成434个batch
# test_set1已完成435个batch
# test_set1已完成436个batch
# test_set1已完成437个batch
# test_set1已完成438个batch
# test_set1已完成439个batch
# test_set1已完成440个batch
# test_set1已完成441个batch
# test_set1已完成442个batch
# test_set1已完成443个batch
# test_set1已完成444个batch
# test_set1已完成445个batch
# test_set1已完成446个batch
# test_set1已完成447个batch
# test_set1已完成448个batch
# test_set1已完成449个batch
# test_set1已完成450个batch
# test_set1已完成451个batch
# test_set1已完成452个batch
# test_set1已完成453个batch
# test_set1已完成454个batch
# test_set1已完成455个batch
# test_set1已完成456个batch
# test_set1已完成457个batch
# test_set1已完成458个batch
# test_set1已完成459个batch
# test_set1已完成460个batch
# test_set1已完成461个batch
# test_set1已完成462个batch
# test_set1已完成463个batch
# test_set1已完成464个batch
# test_set1已完成465个batch
# test_set1已完成466个batch
# test_set1已完成467个batch
# test_set1已完成468个batch
# test_set1已完成469个batch
# test_set1已完成470个batch
# test_set1已完成471个batch
# test_set1已完成472个batch
# test_set1已完成473个batch
# test_set1已完成474个batch
# test_set1已完成475个batch
# test_set1已完成476个batch
# test_set1已完成477个batch
# test_set1已完成478个batch
# test_set1已完成479个batch
# test_set1已完成480个batch
# test_set1已完成481个batch
# test_set1已完成482个batch
# test_set1已完成483个batch
# test_set1已完成484个batch
# test_set1已完成485个batch
# test_set1已完成486个batch
# test_set1已完成487个batch
# test_set1已完成488个batch
# test_set1已完成489个batch
# test_set1已完成490个batch
# test_set1已完成491个batch
# test_set1已完成492个batch
# test_set1已完成493个batch
# test_set1已完成494个batch
# test_set1已完成495个batch
# test_set1已完成496个batch
# test_set1已完成497个batch
# test_set1已完成498个batch
# test_set1已完成499个batch
# test_set1已完成500个batch
# test_set1已完成501个batch
# test_set1已完成502个batch
# test_set1已完成503个batch
# test_set1已完成504个batch
# test_set1已完成505个batch
# test_set1已完成506个batch
# test_set1已完成507个batch
# test_set1已完成508个batch
# test_set1已完成509个batch
# test_set1已完成510个batch
# test_set1已完成511个batch
# test_set1已完成512个batch
# test_set1已完成513个batch
# test_set1已完成514个batch
# test_set1已完成515个batch
# test_set1已完成516个batch
# test_set1已完成517个batch
# test_set1已完成518个batch
# test_set1已完成519个batch
# test_set1已完成520个batch
# test_set1已完成521个batch
# test_set1已完成522个batch
# test_set1已完成523个batch
# test_set1已完成524个batch
# test_set1已完成525个batch
# test_set1已完成526个batch
# test_set1已完成527个batch
# test_set1已完成528个batch
# test_set1已完成529个batch
# test_set1已完成530个batch
# test_set1已完成531个batch
# test_set1已完成532个batch
# test_set1已完成533个batch
# test_set1已完成534个batch
# test_set1已完成535个batch
# test_set1已完成536个batch
# test_set1已完成537个batch
# test_set1已完成538个batch
# test_set1已完成539个batch
# test_set1已完成540个batch
# test_set1已完成541个batch
# test_set1已完成542个batch
# test_set1已完成543个batch
# test_set1已完成544个batch
# test_set1已完成545个batch
# test_set1已完成546个batch
# test_set1已完成547个batch
# test_set1已完成548个batch
# test_set1已完成549个batch
# test_set1已完成550个batch
# test_set1已完成551个batch
# test_set1已完成552个batch
# test_set1已完成553个batch
# test_set1已完成554个batch
# test_set1已完成555个batch
# test_set1已完成556个batch
# test_set1已完成557个batch
# test_set1已完成558个batch
# test_set1已完成559个batch
# test_set1已完成560个batch
# test_set1已完成561个batch
# test_set1已完成562个batch
# test_set1已完成563个batch
# test_set1已完成564个batch
# test_set1已完成565个batch
# test_set1已完成566个batch
# test_set1已完成567个batch
# test_set1已完成568个batch
# test_set1已完成569个batch
# test_set1已完成570个batch
# test_set1已完成571个batch
# test_set1已完成572个batch
# test_set1已完成573个batch
# test_set1已完成574个batch
# test_set1已完成575个batch
# test_set1已完成576个batch
# test_set1已完成577个batch
# test_set1已完成578个batch
# test_set1已完成579个batch
# test_set1已完成580个batch
# test_set1已完成581个batch
# test_set1已完成582个batch
# test_set1已完成583个batch
# test_set1已完成584个batch
# test_set1已完成585个batch
# test_set1已完成586个batch
# test_set1已完成587个batch
# test_set1已完成588个batch
# test_set1已完成589个batch
# test_set1已完成590个batch
# test_set1已完成591个batch
# test_set1已完成592个batch
# test_set1已完成593个batch
# test_set1已完成594个batch
# test_set1已完成595个batch
# test_set1已完成596个batch
# test_set1已完成597个batch
# test_set1已完成598个batch
# test_set1已完成599个batch
# test_set1已完成600个batch
# test_set1已完成601个batch
# test_set1已完成602个batch
# test_set1已完成603个batch
# test_set1已完成604个batch
# test_set1已完成605个batch
# test_set1已完成606个batch
# test_set1已完成607个batch
# test_set1已完成608个batch
# test_set1已完成609个batch
# test_set1已完成610个batch
# test_set1已完成611个batch
# test_set1已完成612个batch
# test_set1已完成613个batch
# test_set1已完成614个batch
# test_set1已完成615个batch
